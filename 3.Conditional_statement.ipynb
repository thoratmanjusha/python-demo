# %% [raw]
# A conditional statement is used to make decision in a program.

# %% [markdown]
# ##### syntax

# %% [raw]
# if condition:
#     statement

# %% [markdown]
# # 1)If Statement

# %% [raw]
# if condition:
#     statement

# %%
age=20
if age>=18:
    print("Eligible for votiong")
# Out:
# Eligible for votiong

# %%
marks=80
if marks>=35: #grater
    print("Pass")
# Out:
# Pass

# %%
temp=40
if temp>35:
    print("high temperature")
# Out:
# high temperature

# %% [markdown]
# # 2)If-----------else Statement

# %% [raw]
# If the condition id True , the if block execute ;
# otherwise
# the else block execute.
#
# Syntax
#
# if condition:
#     statement
# else:
#     Statement

# %% [markdown]
# # Voting

# %%
age=int(input("Enter Your Age::"))
if age>=18:
    print("Eligible for wote")
else:
    print("Not Eligible for voting")
# Out:
# Enter Your Age:: 18
# Eligible for wote

# %% [markdown]
# # Even or Odd

# %%
num=int(input("Enter number::"))
if num%2==0:
    print("Even number")
else:
    print("Odd Number")
# Out:
# Enter number:: 4
# Even number

# %% [markdown]
# # Postitive or Negative number

# %%
num=int(input("Enter Number::"))
if num>=0:
    print("Number is postive")
else:
    print("Negative number")
# Out:
# Enter Number:: 0
# Number is postive

# %% [markdown]
# # 3)if-------elif----else statement

# %% [raw]
# used when there are multiple conditions.
#
# syntx
#
# if condition:
#     statement
# elif condition:
#     statement
# else:
#     statemet

# %% [markdown]
# ##### Marks

# %%
marks=int(input("Enter Marks"))
if marks>=90:
    print("A")
elif marks>=75:
    print("B")
elif marks>=50:
    print("C")
else:
    print("Failed.............")
# Out:
# Enter Marks 56
# C

# %% [markdown]
# # 4)Nested If

# %% [raw]
# An if statement withing another if statement.

# %% [markdown]
# # ATM

# %%
pin=int(input("Enter pin"))
if pin==1234:
    balance=5000
    print("50000")
    if balance>=1000:
        print("Trasaction successful")
    else:
        print("Failed......")
else:
    print("Entered valid pin.....")
# Out:
# Enter pin 1234
# 50000
# Trasaction successful

# %% [markdown]
# # diffenrence between if and elif

# %% [markdown]
# if                                      elif
# -Used to chech the first condition.     used to check another condition if the previous elif condition is false.
# -It is requred at the beginning of      It comes after if or another elif.
# the contion chain
# -You can have multiple separate if      You can have multiple elif condition in one chain.
# statement.
