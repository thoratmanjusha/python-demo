# %% [raw]
# 1)String:-Imutable,ordered,duplicate items are allow,string writen in '' "" ''' ''',
# 2)List:-mutable ,ordered,dupictes item are allowed,[]
# 3)Tuple:-imutable , ordered,ducplicate items are allowed,()
# 4)set:- Mutable, Unordered,duplicated itms are not allowed. set(),{}Set

# %% [markdown]
# # Set Data Typed

# %% [raw]
# 1)Mutable= changable (Add,update,delete)
# 2)It is unorederd.(we can not use indexing and slicing)
# 3)Dupicated items are not allowed.
# 4)It is enclosed by curly braces{}.
# 5)Intitilize with set() empty set.
# 6)set items are comma seperated.

# %%
set1={10,20,30,40,50}
set1
# Out:
# {10, 20, 30, 40, 50}

# %%
set1={10,20,'manjusha','thorat'}
set1
# Out:
# {10, 20, 'manjusha', 'thorat'}

# %%
set1={10,20,'manjusha',20,'thorat'} #dupicate items are not allowed
set1
# Out:
# {10, 20, 'manjusha', 'thorat'}

# %%
set1={10,20,'manjusha',20,'thorat','THORAT'}#case sensitive and unorededa
set1
# Out:
# {10, 20, 'THORAT', 'manjusha', 'thorat'}

# %%
a=list()
type(a)
# Out:
# list

# %%
b=()
type(b)
# Out:
# tuple

# %%
c=" "
type(c)
# Out:
# str

# %%
y=set()
type(y)
# Out:
# set

# %%
s1={3,4,5,6,7,8,"python"}
s1
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
s1={3,4,5,6,7,8,"python",(1,2,3)}
s1  #tuple in set
# Out:
# {(1, 2, 3), 3, 4, 5, 6, 7, 8, 'python'}

# %%
s1={3,4,5,6,7,8,"python",(1,2,3),[1246]}
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 s1={3,4,5,6,7,8,"python",(1,2,3),[1246]}
#       2 s1
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %% [markdown]
# # Typecasting

# %%
list-tuple
list-set

tuple-list
tuple-set

set-list
set-tuple
# Out:
# (2, 3, 4, 5)

# %%
#list to tuple
x=[2,3,4,5]
y=tuple(x)
y
# Out:
# (2, 3, 4, 5)

# %%
#list to set
x=[2,3,4,5]
y=set(x)
y
# Out:
# {2, 3, 4, 5}

# %%
#set to list and tuple
s2={1,2,4,5,6,7}
x=list(s2)
y=tuple(s2)
print(x)
print(y)
# Out:
# [1, 2, 4, 5, 6, 7]
# (1, 2, 4, 5, 6, 7)

# %% [markdown]
# # Access Set Items

# %%
s1={2,3,4,5,6}
for i in s1:
    print(f"i=={i}")
# Out:
# i==2
# i==3
# i==4
# i==5
# i==6

# %%
s1={1,2,3,4,5,'manjusha','thorat',5.64}
print(s1)
for i in s1:
    print(i)
# Out:
# {1, 2, 3, 4, 5, 5.64, 'thorat', 'manjusha'}
# 1
# 2
# 3
# 4
# 5
# 5.64
# thorat
# manjusha

# %%
s1={1,2,3,4,5,'manjusha','thorat',5.64}
for i, val in enumerate(s1):
    print(val)
# Out:
# 1
# 2
# 3
# 4
# 5
# 5.64
# thorat
# manjusha

# %% [markdown]
# # Set Function

# %% [markdown]
# # 1.add()
# 2.update()
# 3.union()
#
# 4.remove()
# 5.discard()
# 6.pop()
# 7.clear
#
# 8.intersection
# 9.intersection_update
# 10.differince
# 11.difference_update
# 12.symmeric_diff
# 13.symmeric_diff_update
# 14.issuperset()
# 15.issubset()
# 16.isdisjoint()

# %% [markdown]
# # 1.add()

# %% [raw]
# It is used to add only one item in set.
# set.add(value)

# %%
s1={3,4,5,6,7,8,9,10}
s1.add(100)
s1
# Out:
# {3, 4, 5, 6, 7, 8, 9, 10, 100}

# %%
s1={50,3,4,5,6,7,8,9,10}
s1.add(100)
s1
# Out:
# {3, 4, 5, 6, 7, 8, 9, 10, 50, 100}

# %%
s1={"pune","Mumbai","delhi","Angr"}
s1.add("Pak")
s1
# Out:
# {'Angr', 'Mumbai', 'Pak', 'delhi', 'pune'}

# %%
s1="python"
x=s1.replace('python','java')
x
# Out:
# 'java'

# %% [markdown]
# # 2.update()

# %% [raw]
# set.update(iterable)
# iterable-set,list,tuple

# %%
x=[2,3,4,5]
y=[30,40,56,76]
x.extend(y)
x
# Out:
# [2, 3, 4, 5, 30, 40, 56, 76]

# %%
x={1,2,3,4,5,6}
y={10,20,30,40,50,60}
y.update(x)
x
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
x={1,2,3,4,5,6}
y={10,20,30,40,50,60}
y.update(x)
y
# Out:
# {1, 2, 3, 4, 5, 6, 10, 20, 30, 40, 50, 60}

# %%
x={1,2,3,4,5,6}
y=[10,20,30,40,50,60]
x.update(y)
y
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
x={1,2,3,4,5,6}
y=[10,20,30,40,50,60]
y.update(x)
x
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 3
#       1 x={1,2,3,4,5,6}
#       2 y=[10,20,30,40,50,60]
# ----> 3 y.update(x)
#       4 x
#
# AttributeError: 'list' object has no attribute 'update'

# %%
x={2,3,4,5,6}
y=[10,20,30,40,50]
z=['python','ml']
x.update(z)
x
# Out:
# {2, 3, 4, 5, 6, 'ml', 'python'}

# %% [markdown]
# # 3.union

# %% [raw]
# retun a set containing the union of sets.
#     new_set.union(iterable)
#     iterable=list,set,tuple

# %%
s1={3,4,5,6,7,8,9}
s2={23,54,65,34,56,75}
s1.update(s2)
print("set 1",s1)
print("set 2",s2)
# Out:
# set 1 {65, 34, 3, 4, 5, 6, 7, 8, 9, 75, 54, 23, 56}
# set 2 {65, 34, 54, 23, 56, 75}

# %%
s1={3,4,5,6,7,8,9}
s2={23,54,65,34,56,75}
new_set=s1.union(s2)
print(s1)
print(s2)
print("new set",new_set)
# Out:
# {3, 4, 5, 6, 7, 8, 9}
# {65, 34, 54, 23, 56, 75}
# new set {65, 34, 3, 4, 5, 6, 7, 8, 9, 75, 54, 23, 56}

# %% [raw]
# update()=affect on original set
# union()=not affect on original set new one set is created.

# %% [markdown]
# ## Delete item of set

# %% [raw]
# 1.remove()
# 2.discard()
# 3.pop()
# 4.clear()

# %% [markdown]
# ##### 1.Remove()

# %% [raw]
# set.remove(value)

# %%
s1={'pune','mumbai','nashik'}
print(s1)
s1.remove('pune')
print(s1)
# Out:
# {'mumbai', 'pune', 'nashik'}
# {'mumbai', 'nashik'}

# %%
s1={'pune','mumbai','nashik'}
print(s1)
s1.remove('zt')
print(s1)
# Out:
# {'mumbai', 'pune', 'nashik'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 3
#       1 s1={'pune','mumbai','nashik'}
#       2 print(s1)
# ----> 3 s1.remove('zt')
#       4 print(s1)
#
# KeyError: 'zt'

# %% [markdown]
# s1={'pune','mumbai','nashik'}
# city='pune'
# if city in s1:
#     s1.remove(city)
#     print("Item delete")
# else:
#     print("Item  not found")

# %% [markdown]
# ### 2.discard()

# %% [raw]
# set.discard(values)
# return original set if item is not present in given set.

# %% [raw]
# s1={'pune','mumbai','nashik'}
# s1.remove('nagar')
# s1

# %%
s1={'pune','mumbai','nashik'}
s1.discard('nagar')
s1
# Out:
# {'mumbai', 'nashik', 'pune'}

# %%
s1={'pune','mumbai','nashik'}
s1.discard('pune')
s1
# Out:
# {'mumbai', 'nashik'}

# %% [markdown]
# #### 3.pop()

# %% [raw]
# set.pop()
# it will delete random item form set.

# %%
s1={'pune','mumbai','nashik'}
s1.pop()
s1
# Out:
# {'nashik', 'pune'}

# %%
s2={1,3,5,5,6,7}
s2.pop()
s2
# Out:
# {3, 5, 6, 7}

# %% [markdown]
# #### 4.clear

# %% [raw]
# return empty set.
# it will delete all items from set.

# %%
s1={'pune','mumbai','nashik'}
s1.clear()
s1
# Out:
# set()

# %% [markdown]
# ### difference between remove(),discard(),pop(),clear()

# %% [raw]
# remove()- removes a specific element . if the element is not present.it raise an error.
# discard()- removes a specific element . if the element is not preset.it does not raise an error.
# pop()-remove a retun and random elemnt from a list.
# clear()-remove all element from the set.

# %% [markdown]
# # 1.Intersection

# %% [raw]
# set.intersection(iterable)
# iterable-list,set,tuple
# intersection returns the common elements between two or more sets.

# %%
list1=[2,3,4,5,8,4,6]
list2=[9,7,5,4,6,8,5]
for i in list1:
    if i in list2:
        print(f"i=={i}")
# Out:
# i==4
# i==5
# i==8
# i==4
# i==6

# %%
list1=[2,3,4,5,8,4,6]
list2=[9,7,5,4,6,8,5]
result=[]
for i in list1:
    if i in list2:
        result.append(i)
print(result)
# Out:
# [4, 5, 8, 4, 6]

# %%
list1=[2,3,4,5,8,4,6]
list2=[9,7,5,4,6,8,5]
result=[i for i in list1 if i in list2]
result
# Out:
# [4, 5, 8, 4, 6]

# %%
set1={2,3,4,5,6,7}
set2={6,5,4,8,5}
result=set1.intersection(set2)
print(set1)
print(set2)
print(result)
# Out:
# {2, 3, 4, 5, 6, 7}
# {8, 4, 5, 6}
# {4, 5, 6}

# %%
list1=[2,3,4,5,8,4,6]
list2=[9,7,5,4,6,8,5]
set1=set(list1).intersection(list2)
set1
# Out:
# {4, 5, 6, 8}

# %%
list1=[1,2,3]
list2=[3,4,5]
list3=[3,7,8]
set1=set(list2)
s2.intersection(list1,list3)
# Out:
# {3}

# %% [markdown]
# #### 2.intersection_update

# %% [raw]
# it does not create new set.
# but only insertion create new set

# %%
set1={2,3,4,5,6,7}
set2={6,5,4,8,5}
set2.intersection_update(set1)
print(set1)
print(set2)
# Out:
# {2, 3, 4, 5, 6, 7}
# {4, 5, 6}

# %%
set1={2,3,4,5,6,7}
set2={6,5,4,8,5}
set1.intersection_update(set2)
print(set1) #it will not retun new set.
print(set2)
# Out:
# {4, 5, 6}
# {8, 4, 5, 6}

# %% [markdown]
# ### 3.difference()

# %%
set1={2,3,4,5,6,7}
set2={9,8,6,5,4}
set3=set1.difference(set2)
print(set3)
# Out:
# {2, 3, 7}

# %% [raw]
#  difference returns the elements that are present in the first set but not in the second set.

# %%
set1={2,3,4,5,6,7}
set2={9,8,6,5,4}
set3=set2.difference(set1)
print(set3)
# Out:
# {8, 9}

# %% [markdown]
# ### 4.difference_update()

# %%
set1={2,3,4,5,6,7,8,9}
set2={9,8,6,5,4}
set1.difference_update(set2)

print(set1)
print(set2)
# Out:
# {2, 3, 7}
# {4, 5, 6, 8, 9}

# %%
set1={2,3,4,5,6,7,8,9}
set2={9,8,6,5,4}
set2.difference_update(set1)

print(set1)
print(set2)
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}
# set()

# %% [markdown]
# # 5.symmeric_difference

# %% [raw]
# unique items for two set.
# set1.symmeric_difference(set2)

# %%
set1={3,5,4}
set2={3,9}
set1.symmetric_difference(set2)
# Out:
# {4, 5, 9}

# %%
set1={3,5,4}
set2={3,9}
set1.symmetric_difference(set2)
# Out:
# {4, 5, 9}

# %% [markdown]
# # 6.symmeric_differnce_update()

# %%
set1={3,5,4}
set2={3,9}
set2.symmetric_difference_update(set1)
print(set1)
print(set2)
# Out:
# {3, 4, 5}
# {9, 4, 5}

# %%
set1={3,5,4}
set2={3,9}
set1.symmetric_difference_update(set2)
print(set1)
print(set2)
# Out:
# {9, 4, 5}
# {9, 3}

# %% [markdown]
# # 6.issuperset()

# %% [raw]
# set1.issuperset(set2)
# true or false

# %%
set1={1,3,4,5,6}
set2={5,4,3}
set1.issuperset(set2)
# Out:
# True

# %%
set1={1,3,4,5,6}
set2={9,8,7}
set1.issuperset(set2)
# Out:
# False

# %% [markdown]
# ## 7.issubset()

# %%
set1={1,3,4,5,6}
set2={9,8,7}
set1.issubset(set2)
# Out:
# False

# %%
set1={1,3,4,5,6}
set2={1,3,5}
set2.issubset(set1)
# Out:
# True

# %% [markdown]
# # 8.isdisjoint()

# %%
set1={2,3,4,5,6,7}
set2={100,200,300,400}
set1.isdisjoint(set2)
# Out:
# True

# %%
set1={2,3,4,5,6,7}
set2={2,3,4}
set1.isdisjoint(set2)
# Out:
# False

# %% [raw]
# issuperset()-check whether one set contain all elements of another set.
# issubset()-check whetherr one set is a subset of another set.
# isdisjoint()-checks whether two sets have no common elemnts.
