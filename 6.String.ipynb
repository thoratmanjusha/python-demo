# %% [raw]
# Sting is a collection of character surrounded by single quotes double quotes, and triple quotes.
# multiline string surrounded by triple single quates and triple double quotes.
# ex('''multiline string'''')("""multiline string """)

# %%
string1="python"
string2='python'
string3='''python'''
string4="""python"""
print(string1)
print(string2)
print(string3)
print(string4)
string1
# Out:
# python
# python
# python
# python
# 'python'

# %%
string1="python and "Data science" ML"
string1
# Out:
#   Cell In[3], line 1
#     string1="python and "Data science" ML"
#                          ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
string1="python and 'Data' science ML"
string1
# Out:
# "python and 'Data' science ML"

# %%
string1='''Sting is a collection of character surrounded by single quotes double quotes, and triple quotes.
multiline string surrounded by triple single quates and triple double quotes.'''
string1
# Out:
# 'Sting is a collection of character surrounded by single quotes double quotes, and triple quotes.\nmultiline string surrounded by triple single quates and triple double quotes.'

# %%
string1="""Sting is a collection of character surrounded by single quotes double quotes, and triple quotes.
multiline string surrounded by triple single quates and triple double quotes."""
string1
# Out:
# 'Sting is a collection of character surrounded by single quotes double quotes, and triple quotes.\nmultiline string surrounded by triple single quates and triple double quotes.'

# %% [markdown]
# # Escape Characters

# %% [raw]
# Backslash is a escape characters.

# %%
string1='python and \'data\'science'
string1
# Out:
# "python and 'data'science"

# %%
s='Sting \n is a collection of character surrounded by single quotes double quotes, and triple quotes'
s
# Out:
# 'Sting \n is a collection of character surrounded by single quotes double quotes, and triple quotes'

# %%
s="C:\Users\Sai\picture"
s
# Out:
#   Cell In[14], line 1
#     s="C:\Users\Sai\picture"
#       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
s="C:\\Users\\Sai\\picture"
s
# Out:
# 'C:\\Users\\Sai\\picture'

# %% [markdown]
# # Indexing and Slicing in string

# %% [raw]
# Indexing is used to access a specific character from a string usding its index position.Indexing will always start from 0.

# %% [markdown]
# #### Positive indexing

# %% [raw]
# string1="python"
# string[0]=p
# string[1]=y
# string[2]=t
# string[3]=h
# string[4]=o
# string[5]=n

# %% [raw]
# Indexing is used to access only one character.
# len() function used for checking length of string.

# %% [raw]
# string= " p  y  t  h  o  n "
# +ve =     0  1  2  3  4  5
# -ve =    -6 -5 -4 -3 -2 -1

# %%
s='python'
x=len(s)
x
# Out:
# 6

# %%
s='python'
x=len(s)
s[x]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 s='python'
#       2 x=len(s)
# ----> 3 s[x]
#
# IndexError: string index out of range

# %%
s='python'
x=len(s)
s[x-1]
# Out:
# 'n'

# %%
s='python'
s[len(s)-1]
# Out:
# 'n'

# %%
x='1234'
len(x)
# Out:
# 4

# %%
x=''
len(x)
# Out:
# 0

# %% [markdown]
# ### Negative indexing

# %% [raw]
# string1="python"
# string[-1]=n
# string[-2]=o
# string[-3]=h
# string[-4]=t
# string[-5]=y
# string[-6]=p

# %%
s="python"
print(s[-1])
print(s[-3])
# Out:
# n
# h

# %% [markdown]
# # Slicing

# %% [raw]
# slicing is used to access one or more character of string.
# slicing is used to access a part of string using a range of index values.
# string[start_index,end_index:[step_size]]
#
# start_index= include
# end_index = exclude
#
# default start index = 0
# defalut end index = len(string)
#
# string= " p  y  t  h  o  n "
# +ve =     0  1  2  3  4  5
# -ve =    -6 -5 -4 -3 -2 -1

# %%
string='python'
print(string[2])
print(string[3])
print(string[4])
# Out:
# t
# h
# o

# %%
string='python'
string[2:5]
# Out:
# 'tho'

# %%
string='python'
string[1:5]
# Out:
# 'ytho'

# %%
s="machine learning"
s[4:9]
# Out:
# 'ine l'

# %%
s="machine learning"
s[3:8]
# Out:
# 'hine '

# %%
string='python'
string[:]
# Out:
# 'python'

# %%
string='python'
string[:0]
# Out:
# ''

# %%
string='python'
string[0:]
# Out:
# 'python'

# %%
string='python'
string[:2]
# Out:
# 'py'

# %%
string='python'
string[2:]
# Out:
# 'thon'

# %%
string='python'
string[:len(string)]
# Out:
# 'python'

# %% [raw]
# string= " p  y  t  h  o  n "
# +ve =     0  1  2  3  4  5
# -ve =    -6 -5 -4 -3 -2 -1

# %%
string="python"
print(string[1:4])#yth
print(string[-5:-1])#yth
print(string[1:-2])#yth
print(string[-5:4])#yth
# Out:
# yth
# ytho
# yth
# yth

# %% [markdown]
# ##### How to find first 5 character from string

# %%
string="Data science and ml"
string[0:5]
# Out:
# 'Data '

# %% [markdown]
# ##### How to find last n character

# %%
string="Data science and ml"
string[-10:]
# Out:
# 'nce and ml'

# %%
string="Data science and ml"
string[-10:-1]
# Out:
# 'nce and m'

# %%
string="python"
string[1:4]
string[4:1]
# Out:
# ''

# %% [markdown]
# # Reverse String

# %% [raw]
# we can reverse string using slicing with [::-1]

# %%
string="python"
string[::-1]
# Out:
# 'nohtyp'

# %%
string="python"
string[5:2:-1]
# Out:
# 'noh'

# %%
string="machine learning"
string[::-2]
# Out:
# 'gire nha'

# %%
string="machine learning"
string[2:8:2]
# Out:
# 'cie'

# %% [markdown]
# # String Property

# %% [raw]
# string is imutable.(can not change)
# string is in ordered.
# Duplicate items are allowed.
# single line string = single and double

# %% [markdown]
# #### 1.capitalize()

# %% [raw]
# first alphabet of string capitalize.

# %%
s="data"
s.capitalize()
# Out:
# 'Data'

# %%
s='data science'
s.capitalize()
# Out:
# 'Data science'

# %% [markdown]
# ## 2.Upper

# %% [raw]
# chage string into uppercase.

# %%
s='data science'
s.upper()
# Out:
# 'DATA SCIENCE'

# %%
s='data science 1234'
s.upper()
# Out:
# 'DATA SCIENCE 1234'

# %%
s='data science 1234 # @ 1234'
s.upper()
# Out:
# 'DATA SCIENCE 1234 # @ 1234'

# %%
s='slicing is used to access one or more character of string.'
s.upper()
# Out:
# 'SLICING IS USED TO ACCESS ONE OR MORE CHARACTER OF STRING.'

# %% [markdown]
# ## 3.lower

# %% [raw]
# it will convert all letters in lowercase.

# %%
s="DATA SCIENCE"
s.lower()
# Out:
# 'data science'

# %%
str1='SLICING IS USED TO ACCESS ONE OR MORE CHARACTER OF STRING.'
str1.lower()
# Out:
# 'slicing is used to access one or more character of string.'

# %% [markdown]
# ## 4.title

# %% [raw]
# first character of every word will be in uppercase.

# %%
s="manjusha thorat"
s.title()
# Out:
# 'Manjusha Thorat'

# %%
s='slicing is used to access one or more character of string.'
s.title()
# Out:
# 'Slicing Is Used To Access One Or More Character Of String.'

# %%
s="MANJUSHA THORAT"
s.title()
# Out:
# 'Manjusha Thorat'

# %%
Adhar_name="manjusha thorat"
p_name="MANJUSHA THORAT"
Adhar_name=p_name.upper()
print("Adadhar Name:",Adhar_name)
print("Pan name:",p_name)

Adhar_name==p_name
# Out:
# Adadhar Name: MANJUSHA THORAT
# Pan name: MANJUSHA THORAT
# True

# %%
Adhar_name="manjusha thorat"
p_name="MANJUSHA THORAT"
Adhar_name=p_name.title()
print("Adadhar Name:",Adhar_name)
print("Pan name:",p_name)
# Out:
# Adadhar Name: Manjusha Thorat
# Pan name: MANJUSHA THORAT

# %% [markdown]
# ## 5.Swapcase

# %% [raw]
# The swapcase method is used to convert uppercase character into lowercase and lowercase character into uppercase.  case chage.

# %%
a_name="manjusha thorat"
a_name.swapcase()
# Out:
# 'MANJUSHA THORAT'

# %%
Str1='MANJUSHA THORAT'
Str1.swapcase()
# Out:
# 'manjusha thorat'

# %% [markdown]
# # 6.lstrip()

# %% [raw]
# It removes leading whitespae from string.

# %%
str1='                     MANJUSHA THORAT'
print(str1.lstrip())
print(str1)
# Out:
# MANJUSHA THORAT
#                      MANJUSHA THORAT

# %% [markdown]
# # 7.rstrip()

# %% [raw]
# It removes all trailing white spaces from string.

# %%
s="python and data science                               "
s.rstrip()
# Out:
# 'python and data science'

# %%
s="                   python and data science                               "
print(s.rstrip())
print(s)
# Out:
#                    python and data science
#                    python and data science

# %% [markdown]
# # 8.strip()

# %% [raw]
# It removes leading and trailling white spaces.

# %%
s="                   python and data science                               "
print(s.strip())
# Out:
# python and data science

# %%
s="                   python and data science                               "
print(s.strip())
print(s)
# Out:
# python and data science
#                    python and data science

# %% [markdown]
# # 9.replace

# %% [raw]
# Replace old substring with new substring.
#
# syntax:- replace("old_string","new_string")

# %%
string1="python and machine learning"
string1.replace("python","Ds")
# Out:
# 'Ds and machine learning'

# %%
string1="python and machine learning"
string1.replace("python and machine learning","Manjusha")
# Out:
# 'Manjusha'

# %% [markdown]
# # 10.count()

# %% [raw]
# count the occurences of the substring in a string.
# syntax:-string.count(substring,[start_index],[end_index])

# %%
s="count the occurences of the substring in a string."
s.count("count")
# Out:
# 1

# %%
s="count the occurences of the substring in a string."
s.count("o")
# Out:
# 3

# %%
s="count the occurences of the substring in a string."
s.count("a")
# Out:
# 1

# %%
s="count the occurences of the substring in a string."
s[0:5]
# Out:
# 'count'

# %%
s="count the occurences of the substring in a string."
s[0:9]
# Out:
# 'count the'

# %%
s="count the occurences of the substring in a string of of of of."
s.count("of",0,40)
# Out:
# 1

# %%
#first string convert into lowercase then count the substring occurances.
s="count the occurences of the substring in a string of of of of."
s.lower().count("of")
# Out:
# 5

# %% [markdown]
# # 11.index()

# %% [raw]
# to find  the index of substring.
# syntax=string.index(substring.[start_index, end_index])

# %%
s="machine learning and deep learning"
s.index("machine")
# Out:
# 0

# %%
s="machine learning and deep learning"
s.index("and")
# Out:
# 17

# %%
s="machine learning and deep learning"
print(s.count("a"))
print(s.index("a"))
# Out:
# 4
# 1

# %%
s="machine learning and deep learning"
s.index("l")
# Out:
# 8

# %% [markdown]
# # 12.find()

# %% [raw]
# To find substring is present in string or not, return index. And it return index.
# styntax:- string.find(substring,[String_index,end_index])
# return index

# %%
s="machine learning and deep learning"
s.index("learning")
# Out:
# 8

# %%
s="machine learning and deep learning"
s.find("learning")
# Out:
# 8

# %%
s="machine learning and deep learning"
s.index("python")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 s="machine learning and deep learning"
# ----> 2 s.index("python")
#
# ValueError: substring not found

# %%
s="machine learning and deep learning"
s.index("learning",10,20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 s="machine learning and deep learning"
# ----> 2 s.index("learning",10,20)
#
# ValueError: substring not found

# %%
s="machine learning and deep learning"
s.index("learning",10)
# Out:
# 26

# %% [markdown]
# # 13.split

# %% [raw]
# The split() method is used to split a string into a list of substring.
# The split() function seperate the given string.
# The defined delimeter i.e. space('')

# %%
s="machine learning and deep learning"
x=s.split()
print(x)
print(s)
print(len(x))
# Out:
# ['machine', 'learning', 'and', 'deep', 'learning']
# machine learning and deep learning
# 5

# %%
s="machine learning and deep learning"
s.split(" ")
# Out:
# ['machine', 'learning', 'and', 'deep', 'learning']

# %%
s="machine learning and deep learning"
s.split(" | ")
# Out:
# ['machine learning and deep learning']

# %%
s="machine learning and deep learning"
x=s.split('and')
print(x)
# Out:
# ['machine learning ', ' deep learning']

# %%
len(x)
# Out:
# 2

# %%
txt="""It is used to convert into list datatypeIt is used to convert into list datatype
It is used to convert into list datatypeIt is used to convert into list datatype
It is used to convert into list datatype"""
txt.split()
# Out:
# ['It',
#  'is',
#  'used',
#  'to',
#  'convert',
#  'into',
#  'list',
#  'datatypeIt',
#  'is',
#  'used',
#  'to',
#  'convert',
#  'into',
#  'list',
#  'datatype',
#  'It',
#  'is',
#  'used',
#  'to',
#  'convert',
#  'into',
#  'list',
#  'datatypeIt',
#  'is',
#  'used',
#  'to',
#  'convert',
#  'into',
#  'list',
#  'datatype',
#  'It',
#  'is',
#  'used',
#  'to',
#  'convert',
#  'into',
#  'list',
#  'datatype']

# %% [markdown]
# # 15.join()

# %% [raw]
# It is used to convert list to string by defined delimeter i.e (" ")
# Syntax:-"substring".join(list)

# %%
list1=["machine","learning","and","data","science"]
" ".join(list1)
# Out:
# 'machine learning and data science'

# %%
list1=["machine","learning","and","data","science"]
"-".join(list1)
# Out:
# 'machine-learning-and-data-science'

# %% [markdown]
# # 16.endswith()

# %% [raw]
# It returns true if string end with substring .

# %%
str1="machine"
str1.endswith("e")
# Out:
# True

# %%
str1="machine"
str1.endswith("d")
# Out:
# False

# %%
str1="machine$"
str1.endswith("e")
# Out:
# False

# %%
str1="machine#"
str1.endswith("#")
# Out:
# True

# %% [markdown]
# # 17.stratswith()

# %% [raw]
# It return true if string starts with substring.

# %%
s="Data science"
s.startswith("D")
# Out:
# True

# %%
s="Data science"
s.startswith("e")
# Out:
# False

# %%
s="Data science"
s.startswith("Data")
# Out:
# True

# %% [markdown]
# # 18.isalnum

# %% [raw]
# The isalnum() method checks whether all characters in a string are alphanumric, meaning letters and nubers.
# isalnum= is alpha numeric
# AlphaNumeric = a-z,A-Z,0-9
# True of False
#
# Space is not allowed.

# %%
s='python'
s.isalnum()
# Out:
# True

# %%
s='python1234'
s.isalnum()
# Out:
# True

# %%
s='python.12354'
s.isalnum()
# Out:
# False

# %% [raw]
# a-z,A-Z
# True or false result type
# space is not allowed.

# %%
s='python'
s.isalpha()
# Out:
# True

# %%
s='PYTHON'
s.isalnum()
# Out:
# True

# %%
s='PYTHON 12324324'
s.isalnum()
# Out:
# False

# %% [markdown]
# # 20.isdecimal

# %% [raw]
# The isdecimal() method checks whether whether all characters in as string are decimal dights.
# 0-9, and unicodes of (0-9)
# space is not allowed.

# %%
num='123456'
num.isdecimal()
# Out:
# True

# %%
num='123456a'
num.isdecimal()
# Out:
# False

# %%
adhar_num='2409 1965 0757'
adhar_num.isdecimal()
# Out:
# False

# %%
adhar_num='2409 1965 0757'
adhar_num=adhar_num.replace(" " ,"")
adhar_num.isdecimal()
# Out:
# True

# %%
s='\u0030'
s.isdecimal() #unicode for 0
# Out:
# True

# %%
s='\u0031'
s.isdecimal() #unicode for 0
# Out:
# True

# %%
s='\u0040'
s.isdecimal() #unicode for 0
# Out:
# False

# %%
s='\u0029'
s.isdecimal() #unicode for 0
# Out:
# False

# %% [markdown]
# # 21.isdigit()

# %% [raw]
# 0-9 and unicode of 0-9 , subscript and superscripts // it checks all characters are digit.

# %%
s='\u00B0'
s.isdigit() #superscripts for power 2
# Out:
# False

# %% [markdown]
# # 22.isnumeric

# %% [raw]
# 0-9 and unicodes of 0-9 ,subscripts and superscripts// in string check all character is numeric or not
# space is not allowed.
# valueger fraction.

# %% [raw]
# U+00BD>>1/2

# %%
s='\u00BD'
s.isnumeric()
# Out:
# True

# %%
s='\u00BD'
s.isdigit()
# Out:
# False

# %% [markdown]
# # 23.isupper()

# %% [raw]
# True if string is in uppercase , otherwise false.
# space is allowed.

# %%
s='python'
s.isupper()
# Out:
# False

# %%
s='PYTHON'
s.isupper()
# Out:
# True

# %% [markdown]
# # 24.islower()

# %% [raw]
# True if string is in lowercase , otherwise return false
# space is allowed.

# %%
s='data science'
s.islower()
# Out:
# True

# %%
s="Data science"
s.islower()
# Out:
# False

# %% [markdown]
# # 25.istitle()

# %% [raw]
# True if string is in titlecase, otherwise false.
# string.istitle()
# space is allowed.

# %%
s='Virat Kohli'
s.istitle()
# Out:
# True

# %%
s='virat kohli'
s.istitle()
# Out:
# False

# %%
s='           Virat Kohli'
s.istitle()
# Out:
# True

# %% [markdown]
# # 26.isspace()

# %% [raw]
# If string only containde space the True
# Result type is True of False

# %%
s1="           "
s1.isspace()
# Out:
# True

# %%
s1="        z"
s1.isspace()
# Out:
# False

# %% [markdown]
# # 27.zfill

# %% [raw]
# Zero filling in result.

# %%
s='4567'
s.zfill(8)
# Out:
# '00004567'

# %% [markdown]
# # All function of String

# %% [raw]
# 1.capitalize() :-It converts the first character of a string to uppercase
# 2.upper():-It converts a string into uppercase
# 3.lower():-It converts a string into lowercase
# 4.caseflod():-It converts a string into lowerase fo case in-sensitive comparsion.
# 5.title() ::-It converts the first character of each word to uppercase.
# 6.lstrip() ::-It removes leading spaces from a string.
# 7.rstrip()::-It removes trailling spaces from a string.
# 8.strip()::-It removes leading spaces  and tralling space from a string.
# 9.swapcase() :- It converts uppercase character into lowercase and lovercase into uppercase.
# 10.replce()::-it replace an old substring with a new substring.
# 11.count():-It counts the occurences of a substring in a string.
# 12.index() :it returns the index of the first occurences of a substring.
# 13.find() :- It returns the index of the first occurences os a substring -1 if not found.
# 14.split() :-It splits a string inot a list of substring.
# 15.join():- It joins elements of an iterable into a single string.
# 16.endswith():-it checks whether a string ends with a specific character or substring.
# 17.startswith():-It checks whether a string starts with a specific character or substring.
#
# 18.isalnum():-It checks whether all characters are letters or numbers.
# 19.isalpha():-it checks whether all characters are decimal digits.
# 20.isdecimal():-It checks whether all characters are decimal dighits.
# 21.isdigit():-it checks whether all characters are digits.
# 22.isnumeric():-it checks whether all characters are numeric characters.
#
# 23.islower():-it checks whether all cased characters are uppercase.
# 24.isupper():-It checks whether all cased characters are uppercase.
# 25.istitle():-It checks whether each word starts with an uppercase letter.
# 26.isspace():-it checks whether each word starts with an uppercase letter.
#
# 27.zfill()
